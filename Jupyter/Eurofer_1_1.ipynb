# %% [markdown]
# # Eurofer Properties Database

# %% [markdown]
# ## Table of Contents
# - [Abstract](#abstract)
# - [Introduction](#introduction)
# - [Section 1: Manufacturing & Heat Treatment](#section-1)
#   - [1.1. Composition](#composition)
#   - [1.2. Heat Treatment](#heat_treatment)
#   - [1.3. Microstructure](#microstructure)
#   - [1.4. Product Forms](#forms)
# - [Section 2: Thermo-physical Properties](#section-2)
#   - [2.1. Density](#density)
#   - [2.2. Thermal Diffusivity](#diffusivity)
#   - [2.3. Specific Heat](#cp)
#   - [2.4. Thermal Conductivity](#conductivity)
#   - [2.5. Coefficient of Thermal Expansion](#expansion)
#   - [2.6. Thermal Emissivity](#emissivity)
#   - [2.7. Electrical Resistivity](#resistivity)
#   - [2.8. Magnetic Properties](#magnetic)
#   - [2.9. Elastic Properties](#elastic)
# - [Section 3: Mechanical Properties](#mechanical)

# %% [markdown]
# <a id="abstract"></a>
# <h2 style="text-align: center;">Abstract</h2>
# <p style="text-align: justify;">
# We present a comprehensive database for the ferritic-martensitic steel Eurofer97.  The database is intended to assist in the mechanical design of components manufactured from reduced activation 9 Cr steels (e.g. Eurofer97), in particular, in a fusion reactor power source.  The database is classified into three main categories: (1) fabrication and microstructure, (2) thermophysical properties, and (3) mechanical properties.  The effects of irradiation (both neutron and ion) on the properties of Eurofer are also discussed. Data for each property is collected from various sources available in the public domain.  The sources of data are given together with links to the original publication for verification or corrections. Various functional forms are developed to describe the properties of Eurofer97 as a function of temperature, and if available, as a function of the irradiation dose.
# </p>

# %% [markdown]
# <a id="introduction"></a>
# <h2>Introduction</h2>

# %% [markdown]
# <a id="section-1"></a>
# <h2>Section 1: Manufacturing & Heat Treatment</h2>
# <a id="composition"></a>
# <h3> 1.1. Composition</h3>

# %% [markdown]
# <table border="1">
#     <tr>
#         <th>Specification</th>
#         <th>Producer analysis, heat 83699/83698 (Ø100 mm/14 mm)</th>
#         <th>IMF analysis, heat 83698, 1.5 mm plate</th>
#         <th>CEA analysis, 3 heats, 5 sizes</th>
#     </tr>
#     <tr>
#         <td>Cr</td>
#         <td>8.50-9.50</td>
#         <td>8.87/8.82</td>
#         <td>9.21</td>
#         <td>8.68-9.04</td>
#     </tr>
#     <tr>
#         <td>C</td>
#         <td>0.09-0.12</td>
#         <td>0.12/0.11</td>
#         <td>0.104</td>
#         <td>0.092-0.117</td>
#     </tr>
#     <tr>
#         <td>Mn</td>
#         <td>0.20-0.60</td>
#         <td>0.42/0.47</td>
#         <td>0.502</td>
#         <td>0.41-0.50</td>
#     </tr>
#     <tr>
#         <td>V</td>
#         <td>0.15-0.25</td>
#         <td>0.19/0.20</td>
#         <td>0.204</td>
#         <td>0.17-0.19</td>
#     </tr>
#     <tr>
#         <td>W</td>
#         <td>1.0-1.2</td>
#         <td>1.10/1.09</td>
#         <td>1.148</td>
#         <td>1.03-1.26</td>
#     </tr>
#     <tr>
#         <td>Ta</td>
#         <td>0.05-0.09</td>
#         <td>0.14/0.13</td>
#         <td>0.14</td>
#         <td>0.10-0.15</td>
#     </tr>
#     <tr>
#         <td>N2</td>
#         <td>0.015-0.045</td>
#         <td>0.018/0.020</td>
#         <td>0.0234</td>
#         <td>0.018-0.0226</td>
#     </tr>
#     <tr>
#         <td>O2</td>
#         <td>max. 0.01</td>
#         <td>0.0013/0.0010</td>
#         <td><0.001</td>
#         <td>0.0005-0.0011</td>
#     </tr>
#     <tr>
#         <td>P</td>
#         <td>max. 0.005</td>
#         <td>0.004/0.005</td>
#         <td><0.04</td>
#         <td>0.011-0.013</td>
#     </tr>
#     <tr>
#         <td>S</td>
#         <td>max. 0.005</td>
#         <td>0.003/0.004</td>
#         <td>0.004</td>
#         <td><0.003</td>
#     </tr>
#     <tr>
#         <td>B</td>
#         <td>max. 0.001*)</td>
#         <td><0.0005/0.001</td>
#         <td><0.01</td>
#         <td><0.001</td>
#     </tr>
#     <tr>
#         <td>Ti</td>
#         <td>max. 0.01</td>
#         <td>0.008/0.005</td>
#         <td>0.004</td>
#         <td>0.001-0.005</td>
#     </tr>
#     <tr>
#         <td>Nb</td>
#         <td>max. 0.001*)</td>
#         <td><0.0010/0.0016</td>
#         <td>12 ppm</td>
#         <td><20 ppm</td>
#     </tr>
#     <tr>
#         <td>Mo</td>
#         <td>max. 0.005*)</td>
#         <td><0.0010/0.0010</td>
#         <td><8</td>
#         <td><20-100</td>
#     </tr>
#     <tr>
#         <td>Ni</td>
#         <td>max. 0.005*)</td>
#         <td><0.007/0.0200</td>
#         <td>214</td>
#         <td>400-600</td>
#     </tr>
#     <tr>
#         <td>Cu</td>
#         <td>max. 0.005*)</td>
#         <td>0.022/0.0016</td>
#         <td>35</td>
#         <td>30-400</td>
#     </tr>
#     <tr>
#         <td>Al</td>
#         <td>max. 0.01*)</td>
#         <td>0.008/0.009</td>
#         <td>51</td>
#         <td>30-40</td>
#     </tr>
#     <tr>
#         <td>Si</td>
#         <td>max. 0.05*)</td>
#         <td>0.07/0.04</td>
#         <td>430</td>
#         <td>300-600</td>
#     </tr>
#     <tr>
#         <td>Co</td>
#         <td>max. 0.005*)</td>
#         <td>0.004/0.006</td>
#         <td>67</td>
#         <td>80-200</td>
#     </tr>
#     <tr>
#         <td>As+Sn+Sb+Zr</td>
#         <td>max. 0.05</td>
#         <td><0.015/0.015</td>
#         <td> </td>
#         <td><65-145</td>
#     </tr>
# </table>

# %% [markdown]
# <a id="heat_treatment"></a>
# <h3> 1.2. Heat Treatment</h3>
# For a heat treatment sequence involving initial austenitization followed by a lower temperature tempering, example stages and their effects on the microstructure of ferritic/martensitic steel are as follows:
#
# 1. **Austenitizing: 979°C for 2 hours, followed by air cooling**
#    - **Purpose**: This stage is aimed at fully austenitizing the steel, converting the initial microstructure (whether ferrite, pearlite, or a mix) to austenite. This high temperature ensures the dissolution of carbides and homogenizes the alloy elements within the steel matrix.
#
# 2. **Tempering: 739°C for 4 hours, followed by air cooling**
#    - **Purpose**: The second stage is significantly lower than the first and serves to temper the martensitic structure formed after the first air cooling. Tempering at this temperature typically leads to a substantial transformation within the microstructure, focusing more on enhancing toughness and ductility while reducing hardness to a controlled extent compared to higher tempering temperatures.
#
#
# #### Expected Microstructure
#
# - **Tempered Martensite**: The quick cooling after the initial austenitization forms martensite, which is hard and brittle. The subsequent tempering at 739°C is essential for modifying this martensite. At this temperature, the martensitic structure undergoes significant changes:
#   - **Carbide Precipitation**: Finer and more evenly distributed carbides form during this tempering stage. These carbides are crucial for increasing the toughness and wear resistance of the steel.
#   - **Relaxation of Martensite**: The brittle martensitic lattice relaxes slightly, reducing internal stresses and thus decreasing the brittleness.
#
# - **Potential Bainitic Transformation**: Depending on the specific alloying elements and their concentrations, tempering at this lower temperature (739°C) might also facilitate the formation of lower bainite. Bainite is a plate-like microstructure that offers a beneficial combination of strength and ductility. Its formation would depend significantly on the alloy composition and the actual cooling rate post-tempering.
#
# - **Retained Austenite Stability**: At this lower tempering temperature, any retained austenite from the first cooling is more likely to remain stable or transform into bainite rather than converting into martensite, which can add to the ductility and toughness of the final product.
#
# The image below depicts the expected microstructure of tempered martensitic steel. It shows finely dispersed carbides within a martensitic matrix, typical for steel that has been tempered at lower temperatures.

# %% [markdown]
# <figure>
#    <img src="Eurofer/Figures/Tempered_martensite.webp" alt="Steel microstructure", width="80%">
#     <figcaption>Fig.1 - Microstructure of tempered martensitic steel. It shows finely dispersed carbides within a martensitic matrix, typical for steel that has been tempered at lower temperatures.</figcaption>
# </figure>

# %% [markdown]
# 3. **Aging: 600°C for 5000 hours**
# **Long-term aging** at 600°C for 5000 hours is a specific type of annealing used primarily to understand and enhance the stability of ferritic/martensitic steels under prolonged thermal exposure. This process is particularly relevant in power generation and aerospace applications where components may experience elevated temperatures for extended periods.
#
# ##### Goals of the Annealing Process
# 1. **Stabilize the Microstructure**: Continuous exposure at 600°C aims to stabilize the microstructure against changes during future operational use.
# 2. **Optimize Mechanical Properties**: The process intends to balance ductility, toughness, and strength, making the steel suitable for long-term applications at high temperatures.
#
# #### Expected Microstructural Changes
# 1. **Precipitation and Growth of Carbides**: At 600°C, you can expect the precipitation of various carbides, such as M<sub>23</sub>C<sub>6</sub> (where M can be Cr, Fe), and their growth or coalescence over the extended period. This affects the steel's hardness and tensile strength.
# 2. **Formation of Laves Phase**: In some ferritic/martensitic steels, especially those with high alloy content, a Fe<sub>2</sub>Mo-type Laves phase can form, which could influence creep resistance negatively by depleting the matrix of beneficial alloying elements like W and Mo.
# 3. **Spheroidization of Existing Carbides**: If the material has undergone previous treatments that formed pearlite or other lamellar structures, spheroidization might occur, leading to a more ductile microstructure.
#
# #### Impact on Properties
# - **Decrease in Hardness and Strength**: Due to the growth and coalescence of carbides, the material might lose some hardness and tensile strength.
# - **Increase in Toughness and Ductility**: The spheroidization and stabilization processes tend to increase material ductility and fracture toughness, which are critical for components that undergo thermal cycling.
# - **Potential Decrease in Creep Resistance**: The formation of Laves phases and the growth of large carbides can reduce the creep resistance, an essential factor for high-temperature applications.

# %% [markdown]
# <a id="microstructure"></a>
# <h3> 1.3. Microstructure</h3>
#
# <figure>
#     <img src="Eurofer/Figures/Eurofer_Grain_Structure.jpg" alt="Orientation image maps from EBSD data" style="width:80%;">
#     <figcaption>Fig.2 - Orientation image maps from EBSD data of ODS-Eurofer steel austenitized at different temperatures (60×40 μm², step size 40 nm).</figcaption>
# </figure>
#
#  <figure>
#     <img src="Eurofer/Figures/Eurofer_Grain_Size.jpg" alt="Grain Size" style="width:80%;">
#     <figcaption>Fig.3 - Mean grain size dependence on austenitizing temperature.</figcaption>
# </figure>
#
# Source of Figures: [Zilnyk2015](https://drive.google.com/file/d/1WtQjD-8v5ed6xC_1eBofhYG44xYSPt6v/view?usp=drive_link)

# %% [markdown]
# <a id="product"></a>
# <h3> 1.4. Product Forms</h3>

# %% [markdown]
# <a id="section-2"></a>
# <h2>Section 2: Thermophysical Properties</h2>

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/path/to/Utilities')

from Utilities.models_1_1 import *
from Utilities.plots_1_1 import *


excel_filename = 'Eurofer/Eurofer_data_1_1.xlsx'
material_name = "Eurofer"

# Temperature range and initializations
T = np.arange(300, 1000, 10)
n = len(T)
RT = 273
f_size = 10
legend_size = 6
m_size = 60

# %% [markdown]
# <a id="density"></a>
# <h3>2.1. Density</h3>

# %%
# Load excel data for desired property name
material_property = "Density"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=7)

x_label = 'Temperature [K]'
y_label = r'$\rho$ [Kg/m$^3$]'
x_lim = [290, 1000]
y_lim = [0, 10000]
data_labels = ['Tavassoli2004a']
display(Markdown('Data source: [Tavassoli2004a](https://drive.google.com/file/d/1MIqQqASaKHNNw1S1WN10kY6QAHw2bBct/view?usp=drive_link)'))

# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data

p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer Density','best', legend_font_size= 8)

density_coef = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def Density(T):
    return sum(density_coef[i] * T**i for i in range(len(density_coef)))
# Out:
#    EUROFER97TempK  EUROFER97DensityKg_m_3
# 0             293                    7750
# 1             373                    7728
# 2             473                    7699
# 3             573                    7666
# 4             673                    7633
# 5             773                    7596
# 6             873                    7558
# Data source: [Tavassoli2004a](https://drive.google.com/file/d/1MIqQqASaKHNNw1S1WN10kY6QAHw2bBct/view?usp=drive_link)
# <hr>
# **Fitting parameters for Eurofer Density**
# [[Model]]
#     Model(polynomial)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 7
#     # variables        = 4
#     chi-square         = 0.93153508
#     reduced chi-square = 0.31051169
#     Akaike info crit   = -6.11782107
#     Bayesian info crit = -6.33418047
#     R-squared          = 0.99996842
# [[Variables]]
#     c0:  7815.18138 +/- 7.14476317 (0.09%) (init = 1)
# ...

# %% [markdown]
# Data Source:[Tavassoli 2004](https://github.com/ZapOrg/ZapRepo/blob/main/RAFM%20Steels/Eurofer/Tavassoli2004--Fusion%20Demo%20Interim%20Structural%20Design%20Criteria%20(DISDC).pdf.pdf)

# %% [markdown]
# <a id=diffusivity></a>
# <h3>2.2. Thermal Diffusivity</h3>

# %%
material_property = "Diffusivity"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=8)
x_label = 'Temperature [K]'
y_label = r'$Diffusivity$ cm$^2$/s]'
x_lim = [290, 1000]
y_lim = [0, 0.1]
data_labels = ['Mergia']
display(Markdown('Data source: [Megia2008](https://drive.google.com/file/d/1PJDQARGLnKBRXKxyHsmBi1k_AfUufuEY/view?usp=drive_link)'))


# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer thermal diffusivity','lower left', legend_font_size= 10)
diffusivity_coef = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def ThermalDiffusivity(T):
    return sum(diffusivity_coef[i] * T**i for i in range(len(diffusivity_coef)))
# Out:
#    EUROFER97MergiaTempK  EUROFER97MergiaThermalDiffusivityCoefcm2/s
# 0            295.595855                                    0.081641
# 1            322.797927                                    0.080790
# 2            373.316062                                    0.077536
# 3            472.797927                                    0.075784
# 4            573.056995                                    0.070729
# 5            673.316062                                    0.064822
# 6            772.797927                                    0.058014
# 7            873.056995                                    0.050256
# Data source: [Megia2008](https://drive.google.com/file/d/1PJDQARGLnKBRXKxyHsmBi1k_AfUufuEY/view?usp=drive_link)
# <hr>
# **Fitting parameters for Eurofer Diffusivity**
# [[Model]]
#     Model(polynomial)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 8
#     # variables        = 4
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.3. Specific Heat</h3>

# %%
material_property = "Specific Heat"
var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=24)
x_label = 'Temperature [K]'
y_label = r'Specific Heat [J/Kg.K]'
x_lim = [290, 1000]
y_lim = [0, 1200]
data_labels = ['Mergia','Chun']
display(Markdown('Data sources: [Megia2008](https://drive.google.com/file/d/1PJDQARGLnKBRXKxyHsmBi1k_AfUufuEY/view?usp=drive_link), [Chun2015](https://drive.google.com/file/d/1QxovNvh7x0Sc-3EJGdv9H9zT2BlxhsmZ/view?usp=drive_link)'))

# Concatenate and sort data for fitting?
vars_x = variables[::2] 
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer specific heat','lower left', legend_font_size= 10)

cp_coef = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def SpecificHeat(T):
    return sum(cp_coef[i] * T**i for i in range(len(cp_coef)))
# Out:
#     Mergia2008TempK  Mergia2008SpecificHeatJ/kgK  Chun2015TempK  \
# 0        296.103896                   448.395379      293.54795
# 1        322.727273                   461.489089      326.42466
# 2        348.051948                   475.353017      373.00000
# 3        373.376623                   485.365854      425.05479
# 4        398.051948                   496.148909      474.36986
# 5        423.376623                   504.621309      523.68493
# 6        447.402597                   513.863928      573.00000
# 7        472.727273                   521.566110      622.31507
# 8        498.051948                   530.038511      671.63014
# 9        522.727273                   536.970475      723.68493
# 10       548.051948                   544.672657      773.00000
# 11       572.727273                   550.834403      822.31507
# 12       598.051948                   556.996149      871.63014
# 13       622.727273                   565.468549      920.94521
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.4. Conductivity</h3>

# %%
material_property = "Conductivity"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=13)
x_label ='Temperature [K]'
y_label =r'Conductivity [W/m.K]'
x_lim = [290, 1000]
y_lim = [0, 40]
data_labels = ['Mergia','Chun']
display(Markdown('Data sources: [Megia2008](https://drive.google.com/file/d/1PJDQARGLnKBRXKxyHsmBi1k_AfUufuEY/view?usp=drive_link), [Chun2015](https://drive.google.com/file/d/1QxovNvh7x0Sc-3EJGdv9H9zT2BlxhsmZ/view?usp=drive_link)'))

# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer thermal conductivity','lower left', legend_font_size= 10)

k_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def ThermalConductivity(T):
    return sum(k_coeff[i] * T**i for i in range(len(k_coeff)))
# Out:
#     Mergia2008TempK  Mergia2008ThermalConductivitykW/mK  Chun2015TempK1  \
# 0        295.833333                           28.330097       293.54795
# 1        322.619048                           28.932039       323.68493
# 2        372.619048                           29.194175       375.73973
# 3        473.214286                           30.669903       425.05479
# 4        572.619048                           30.194175       474.36986
# 5        672.619048                           29.330097       526.42466
# 6        772.619048                           29.446602       573.00000
# 7        872.619048                           31.174757       625.05479
# 8               NaN                                 NaN       674.36986
# 9               NaN                                 NaN       723.68493
# 10              NaN                                 NaN       775.73973
# 11              NaN                                 NaN       825.05479
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.5. Resistivity</h3>

# %%
material_property = "Resistivity"
var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=23)
x_label='Temperature [K]'
y_label=r'Resistivity [$\times 10^{-8} \Omega$.m]'
x_lim=[300, 1000]
y_lim=[0, 140]
data_labels = ['Mergia', 'Tavassoli 2004']
display(Markdown('Data sources: [Megia2008](https://drive.google.com/file/d/1PJDQARGLnKBRXKxyHsmBi1k_AfUufuEY/view?usp=drive_link),\
[Tavassoli2004a](https://drive.google.com/file/d/1MIqQqASaKHNNw1S1WN10kY6QAHw2bBct/view?usp=drive_link)'))

# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer electrical resistivity','lower left', legend_font_size= 10)

rho_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def ElectricalResistivity(T):
    return sum(rho_coeff[i] * T**i for i in range(len(rho_coeff)))
# Out:
#     EUROFER97MergiaTempK  EUROFER97MergiaElectricalResistivityx108ohmm  \
# 0             303.317972                                     51.077844
# 1             327.649770                                     54.550898
# 2             344.239631                                     56.467066
# 3             365.806452                                     59.101796
# 4             396.221198                                     62.814371
# 5             423.317972                                     66.407186
# 6             450.414747                                     69.281437
# 7             467.004608                                     71.437126
# 8             497.419355                                     75.508982
# 9             523.410138                                     77.425150
# 10            545.529954                                     81.137725
# 11            577.050691                                     84.730539
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.6. CTE</h3>

# %%
material_property = "CTE"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=7)

x_label='Temperature [K]'
y_label=r'CTE [$10^{-6}$/K]'
x_lim=[300, 1000]
y_lim=[0, 15]
data_labels = ['Chun']
display(Markdown('Data source: [Chun2015](https://drive.google.com/file/d/1QxovNvh7x0Sc-3EJGdv9H9zT2BlxhsmZ/view?usp=drive_link)'))


# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer coefficient of thermal expansion','lower left', legend_font_size= 12)

CTE_coef = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def CTE(T):
    return sum(CTE_coef[i] * T**i for i in range(len(CTE_coef)))
# Out:
#    EUROFER97TempC  EUROFER97CoefficientofThermalExpansion
# 0             100                               10.689873
# 1             200                               11.044304
# 2             300                               11.386076
# 3             400                               11.696203
# 4             500                               11.987342
# 5             600                               12.246835
# 6             700                               12.487342
# Data source: [Chun2015](https://drive.google.com/file/d/1QxovNvh7x0Sc-3EJGdv9H9zT2BlxhsmZ/view?usp=drive_link)
# <hr>
# **Fitting parameters for Eurofer CTE**
# [[Model]]
#     Model(polynomial)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 7
#     # variables        = 4
#     chi-square         = 2.5751e-05
#     reduced chi-square = 8.5838e-06
#     Akaike info crit   = -79.5905308
#     Bayesian info crit = -79.8068902
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.7. Emissivity</h3>

# %%
material_property = "Emissivity"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=5)
x_label = 'Temperature [K]'
y_label = r'Normal Emissivity'
x_lim=[340, 1000]
y_lim=[0, 0.3]
data_labels = ['Echániz polished Normal']
display(Markdown('Data source: [Echaniz2021](https://drive.google.com/file/d/1R--IcJwy-Frr6Qgmk2nLzMMtuwO5uZSP/view?usp=sharing)'))

vars_x = variables[::2]
vars_y = variables[1::2]

# Creating lists with only the first column
x_data_list = [vars_x[2]]
y_data_list = [vars_y[2]]
# Extract only the third element from vars_x and vars_y
T_data = x_data_list
Y_data = y_data_list
data_marker_sizes = [2*m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer polished normal emissivity','best', legend_font_size= 10)

emit1_coef = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def NormalEmissivity(T):
    return sum(emit1_coef[i] * T**i for i in range(len(emit1_coef)))
# Out:
#    Echaniz2021AsrolledTempK  Echaniz2021AsrolledHemisphericalEmissivity  \
# 0                473.100872                                    0.180080
# 1                573.225405                                    0.214688
# 2                672.976339                                    0.245272
# 3                772.727273                                    0.273843
# 4                872.851806                                    0.302012
#
#    Echaniz2021PolishedTempK1  Echaniz2021PolishedHemisphericalEmissivity1  \
# 0                 430.136986                                     0.116901
# 1                 524.283935                                     0.128974
# 2                 624.034869                                     0.142656
# 3                 724.906600                                     0.156338
# 4                 820.921544                                     0.176459
#
#    Echaniz2021polishedTempK2  Echaniz2021polishedNormalEmissivity
# ...

# %%
material_property = "Emissivity"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=5)
x_label = 'Temperature [K]'
y_label = r'Rolled Hemispherical Emissivity'
x_lim=[340, 1000]
y_lim=[0, 0.5]
data_labels = ['Echániz Rolled Hemispherical Emissivity']
display(Markdown('Data source: [Echaniz2021](https://drive.google.com/file/d/1R--IcJwy-Frr6Qgmk2nLzMMtuwO5uZSP/view?usp=sharing)'))

vars_x = variables[::2]
vars_y = variables[1::2]

# Creating lists with only the first column
x_data_list = [vars_x[0]]
y_data_list = [vars_y[0]]
# Extract only the first element from vars_x and vars_y
T_data = x_data_list
Y_data = y_data_list
data_marker_sizes = [2*m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer Rolled Hemispherical Emissivity','best', legend_font_size= 8)

emit2_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def RolledHemisphericalEmissivity(T):
    return sum(emit2_coeff[i] * T**i for i in range(len(emit2_coeff)))
# Out:
#    Echaniz2021AsrolledTempK  Echaniz2021AsrolledHemisphericalEmissivity  \
# 0                473.100872                                    0.180080
# 1                573.225405                                    0.214688
# 2                672.976339                                    0.245272
# 3                772.727273                                    0.273843
# 4                872.851806                                    0.302012
#
#    Echaniz2021PolishedTempK1  Echaniz2021PolishedHemisphericalEmissivity1  \
# 0                 430.136986                                     0.116901
# 1                 524.283935                                     0.128974
# 2                 624.034869                                     0.142656
# 3                 724.906600                                     0.156338
# 4                 820.921544                                     0.176459
#
#    Echaniz2021polishedTempK2  Echaniz2021polishedNormalEmissivity
# ...

# %%
material_property = "Emissivity"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=5)
x_label = 'Temperature [K]'
y_label = r'Polished Hemispherical Emissivity'
x_lim=[340, 1000]
y_lim=[0, 0.5]
data_labels = ['Echániz Polished Hemispherical Emissivity']
display(Markdown('Data source: [Echaniz2021](https://drive.google.com/file/d/1R--IcJwy-Frr6Qgmk2nLzMMtuwO5uZSP/view?usp=sharing)'))

vars_x = variables[::2]
vars_y = variables[1::2]

# Creating lists with only the first column
x_data_list = [vars_x[1]]
y_data_list = [vars_y[1]]
# Extract only the first element from vars_x and vars_y
T_data = x_data_list
Y_data = y_data_list
data_marker_sizes = [2*m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer Polished Hemispherical Emissivity','best', legend_font_size= 8)

emit3_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def PolishedHemisphericalEmissivity(T):
    return sum(emit3_coeff[i] * T**i for i in range(len(emit3_coeff)))
# Out:
#    Echaniz2021AsrolledTempK  Echaniz2021AsrolledHemisphericalEmissivity  \
# 0                473.100872                                    0.180080
# 1                573.225405                                    0.214688
# 2                672.976339                                    0.245272
# 3                772.727273                                    0.273843
# 4                872.851806                                    0.302012
#
#    Echaniz2021PolishedTempK1  Echaniz2021PolishedHemisphericalEmissivity1  \
# 0                 430.136986                                     0.116901
# 1                 524.283935                                     0.128974
# 2                 624.034869                                     0.142656
# 3                 724.906600                                     0.156338
# 4                 820.921544                                     0.176459
#
#    Echaniz2021polishedTempK2  Echaniz2021polishedNormalEmissivity
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.8. Elastic Properties</h3>

# %%
material_property = "Elastic Properties"
var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=18)
x_label = 'Temperature [K]'
y_label = 'Elastic modulus, E [GPa]'
x_lim=[300, 1000]
y_lim=[0, 250]
headings = df.columns
data_labels = [headings[1]]
df = df[['Tavassoli2002TempK', 'Tavassoli2002EGpa']].dropna()

# Convert to lists
T_data = [df['Tavassoli2002TempK'].tolist()]
Y_data = [df['Tavassoli2002EGpa'].tolist()]

data_marker_sizes = [m_size] * len(T_data)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(T_data, Y_data, T, fit_result, f_size, data_marker_sizes, x_label, y_label, x_lim, y_lim, data_labels,\
          "Eurofer Young's modulus",'best', legend_font_size= 10)

Young_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def YoungsModulus(T):
    return sum(Young_coeff[i] * T**i for i in range(len(Young_coeff)))


display(Markdown('Data source: [Tavassoli2002](https://drive.google.com/file/d/1Nsoesbbd3rxN5FvH4YHBmJVacFU83ctA/view?usp=drive_link)'))
# Out:
#     Tavassoli2002TempK  Tavassoli2002EGpa  Tavassoli20021TempK1  \
# 0           374.766974         215.900179            375.654306
# 1           412.109950         215.876805            412.453247
# 2           474.554014         212.849671            474.310642
# 3           540.898251         210.019299            541.765598
# 4           603.342315         206.992166            601.968239
# 5           668.562510         205.556920            668.859175
# 6           732.687974         201.134312            729.069811
# 7           793.453303         199.104245            793.715328
# 8           858.121469         196.872532            857.256787
# 9                  NaN                NaN            920.804908
# 10                 NaN                NaN            979.910155
# 11                 NaN                NaN           1044.574324
# 12                 NaN                NaN           1108.683800
# 13                 NaN                NaN           1172.253239
# ...

# %%
material_property = "Elastic Properties"
x_label = 'Temperature [K]'
y_label = 'Shear modulus, G [GPa]'
x_lim=[300, 1000]
y_lim=[0, 100]

var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=18)
headings = df.columns
data_labels = [headings[3]]

SelectedFrame = df[['Tavassoli20021TempK1', 'Tavassoli20021GGpa']].dropna()
# Convert to lists
T_data = [SelectedFrame['Tavassoli20021TempK1'].tolist()]
Y_data = [SelectedFrame['Tavassoli20021GGpa'].tolist()]

data_marker_sizes = [m_size] * len(T_data)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(T_data, Y_data, T, fit_result, f_size, data_marker_sizes, x_label, y_label, x_lim, y_lim, \
          data_labels,'Eurofer shear modulus','best', legend_font_size= 8)

display(Markdown('Data source: [Tavassoli2002](https://drive.google.com/file/d/1Nsoesbbd3rxN5FvH4YHBmJVacFU83ctA/view?usp=drive_link)'))

Shear_Coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def ShearModulus(T):
    return sum(Shear_Coeff[i] * T**i for i in range(len(Shear_Coeff)))
# Out:
#     Tavassoli2002TempK  Tavassoli2002EGpa  Tavassoli20021TempK1  \
# 0           374.766974         215.900179            375.654306
# 1           412.109950         215.876805            412.453247
# 2           474.554014         212.849671            474.310642
# 3           540.898251         210.019299            541.765598
# 4           603.342315         206.992166            601.968239
# 5           668.562510         205.556920            668.859175
# 6           732.687974         201.134312            729.069811
# 7           793.453303         199.104245            793.715328
# 8           858.121469         196.872532            857.256787
# 9                  NaN                NaN            920.804908
# 10                 NaN                NaN            979.910155
# 11                 NaN                NaN           1044.574324
# 12                 NaN                NaN           1108.683800
# 13                 NaN                NaN           1172.253239
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.9. Hardness</h3m>

# %%
material_property = "Hardness"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=12)
x_label = 'Temperature [K]'
y_label = 'Hardness [HV30]'
x_lim=[0, 1200]
y_lim=[0, 500]
data_labels = ['Heat993391_1040C','Heat993402_1040C','Heat993391_980C','Heat993402_980C']

#Concatenate and sort data for fitting
vars_x = [RT + x for x in variables[::2]]
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)
T = np.arange(300, 1300, 10)
n = len(T)
# Fit the data
p = [1, 1,1,1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes, x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer hardness','best', legend_font_size= 6)


display(Markdown('Data source: [Schaefer2000](https://drive.google.com/file/d/1SU0uSAMExpNDlM0tSGPHX0O3RnZh3d3g/view?usp=drive_link)'))

Hardness_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def Hardness(T):
    return sum(Hardness_coeff[i] * T**i for i in range(len(Hardness_coeff)))
# Out:
#     Schaefer2000Heat993391_1040CTemperingTempC  \
# 0                                           20
# 1                                          650
# 2                                          700
# 3                                          725
# 4                                          775
# 5                                          825
# 6                                          850
# 7                                          950
# 8                                         1000
# 9                                         1050
# 10                                        1100
# 11                                        1150
#
#     Schaefer2000Heat993391_1040CHardness  \
# 0                             410.294118
# 1                             310.539216
# 2                             264.705882
# 3                             237.745098
# 4                             204.656863
# 5                             234.803922
# 6                             299.509804
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.10. Yield Strength</h3m>

# %%
material_property = "Yield Strength"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=15)
x_label = 'Temperature [K]'
y_label = 'Yield Strength [MPa]'
x_lim=[RT, 1000]
y_lim=[0, 900]
data_labels = ['Chun2015','Aillo2011','Rieth2003(979C 2h+739C 4h)','Rieth2003(1075C 0.5h+750C 2h)','Rieth2003( 980 °C 27min + 760 °C 90min)',
'Rieth2003( 1075 °C 30min + 750 °C 2h)','Rieth2003(950 °C 30min + 750 °C 2h)','Rieth2003( 600 °C 1050h)','Rieth2003(  580 °C 3300h)',
'Rieth2003(1075 °C + 750 °C + 600 °C 1050h']

display(Markdown('Data sources: [Rieth2003](https://drive.google.com/file/d/1RAZvEfS86f9VIa6HI1LbvRLpuwSAl8jf/view?usp=sharing), \
[Aillo2011](https://drive.google.com/file/d/1QlfT7DE8DbNop-vl-J2oJIgUBri_-q7l/view?usp=drive_link)'))

#Concatenate and sort data for fitting
vars_x = [RT + x for x in variables[::2]]
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer97 Yield Strength','best', legend_font_size=5)

Yield_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def YieldStrength(T):
    return sum(Yield_coeff[i] * T**i for i in range(len(Yield_coeff)))
# Out:
#     Chun2015TempC  Chun2015YieldStrengthMPa  Aillo2011TempC1  \
# 0              20                547.858099             20.0
# 1              50                525.368139            100.0
# 2             100                508.768407            150.0
# 3             150                494.846051            200.0
# 4             200                486.278447            250.0
# 5             250                479.317269            300.0
# 6             300                471.820616            350.0
# 7             350                462.717537            400.0
# 8             400                448.795181            450.0
# 9             450                427.376171            500.0
# 10            500                397.925033            550.0
# 11            550                355.622490            600.0
# 12            600                299.933066            650.0
# 13            650                228.179384            700.0
# ...

# %%
material_property = "Ultimate Strength"
var_names, variables, dataframe = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=15)
x_label = 'Temperature [K]'
y_label = 'Ultimate Strength [MPa]'
x_lim=[RT, 1000]
y_lim=[0, 900]
data_labels = ['Chun2015','Aillo2011','Rieth2003(979C 2h+739C 4h)','Rieth2003(1075C 0.5h+750C 2h)','Rieth2003( 980 °C 27min + 760 °C 90min)',
'Rieth2003( 1075 °C 30min + 750 °C 2h)','Rieth2003(950 °C 30min + 750 °C 2h)','Rieth2003( 600 °C 1050h)','Rieth2003(  580 °C 3300h)',
'Rieth2003(1075 °C + 750 °C + 600 °C 1050h']

#Concatenate and sort data for fitting
vars_x = [RT + x for x in variables[::2]]
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(x_data_list, y_data_list, T, fit_result, f_size, data_marker_sizes,\
          x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer97 Ultimate Strength','best', legend_font_size=5)

display(Markdown('Data sources: [Rieth2003](https://drive.google.com/file/d/1RAZvEfS86f9VIa6HI1LbvRLpuwSAl8jf/view?usp=sharing), \
[Aillo2011](https://drive.google.com/file/d/1QlfT7DE8DbNop-vl-J2oJIgUBri_-q7l/view?usp=drive_link)'))

Ultimate_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def UltimateStrength(T):
    return sum(Ultimate_coeff[i] * T**i for i in range(len(Ultimate_coeff)))
# Out:
#     Aiello2011TempC  Aiello2011UltimateTensileStrengthMPa  \
# 0              20.0                             634.60653
# 1             100.0                             593.93268
# 2             150.0                             570.30981
# 3             200.0                             551.91572
# 4             250.0                             534.82883
# 5             300.0                             515.12754
# 6             350.0                             495.42626
# 7             400.0                             466.57318
# 8             450.0                             432.49275
# 9             500.0                             389.26197
# 10            550.0                             339.49809
# 11            600.0                             276.65653
# 12            650.0                             199.44013
# 13            700.0                             105.22734
# 14              NaN                                   NaN
#
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.11. Total Elongation</h3m>

# %%
material_property = "Total Elongation"
var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=16)
x_label = 'Temperature [K]'
y_label = 'Total Elongation [%]'
x_lim=[RT, 1000]
y_lim=[0, 40]
headings = df.columns
data_labels = [headings[1], headings[3], headings[5], headings[7]]


# Concatenate and sort data for fitting
vars_x = [RT + x for x in variables[::2]]
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
data_marker_sizes = [m_size] * len(x_data_list)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(vars_x, vars_y, T, fit_result, f_size, data_marker_sizes, x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer97 Total Elongation','best', legend_font_size=5)

display(Markdown('Data sources: [Chun2015](https://drive.google.com/file/d/1S41tqgQpeOffpNkjPO0kletbIjfWxWjq/view?usp=drive_link), \
[Ven der Schaaf2003](https://drive.google.com/file/d/1RO3nRZeOyEc4HsxgEPQawt9KSrOYnYzn/view?usp=drive_link)'))

Total_e_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def TotalElongation(T):
    return sum(Total_e_coeff[i] * T**i for i in range(len(Total_e_coeff)))
# Out:
#     Chun2015TempC  Chun2015TotalElongation%  Schaaf2003ARTempC1  \
# 0            20.0                 22.638266           21.830283
# 1            50.0                 21.330344           21.043839
# 2           100.0                 19.686099          353.854550
# 3           150.0                 18.191330          447.824471
# 4           200.0                 17.443946          596.788936
# 5           250.0                 17.219731          646.643298
# 6           300.0                 17.219731                 NaN
# 7           350.0                 17.668161                 NaN
# 8           400.0                 18.452915                 NaN
# 9           450.0                 19.872945                 NaN
# 10          500.0                 21.479821                 NaN
# 11          550.0                 23.609865                 NaN
# 12          600.0                 26.263079                 NaN
# 13          650.0                 28.654709                 NaN
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.12. Uniform Elongation</h3m>

# %%
material_property = "Uniform Elongation"
var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=7)
x_label = 'Temperature [K]'
y_label = 'Uniform Elongation [%]'
x_lim=[RT, 1000]
y_lim=[0, 10]
headings = df.columns
data_labels = [headings[1], headings[3], headings[5], headings[7]]

# Concatenate and sort data for fitting
vars_x = [RT + x for x in variables[::2]]
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
data_marker_sizes = [m_size] * len(vars_x)

# Fit the data
p = [1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='poly', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)

plot_data(vars_x, vars_y, T, fit_result, f_size, data_marker_sizes, x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer97 Uniform Elongation','best', legend_font_size=6)

display(Markdown('Data sources: [Chun2015](https://drive.google.com/file/d/1S41tqgQpeOffpNkjPO0kletbIjfWxWjq/view?usp=drive_link), \
[Ven der Schaaf2003](https://drive.google.com/file/d/1RO3nRZeOyEc4HsxgEPQawt9KSrOYnYzn/view?usp=drive_link)'))

Uniform_e_coeff = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def UniformElongation(T):
    return sum(Uniform_e_coeff[i] * T**i for i in range(len(Uniform_e_coeff)))
# Out:
#    Chun2015TempC  Chun2015UniformElongation%  Schaaf2003ARTempC1  \
# 0      20.392553                    6.355081           18.254287
# 1      98.942941                    6.368682          359.158447
# 2     199.546625                    5.336616          693.229010
# 3     302.777683                    4.357546                 NaN
# 4     400.235419                    4.020661                 NaN
# 5     501.762352                    2.560959                 NaN
# 6     600.217371                    1.101771                 NaN
#
#    Schaaf2003ARUniformElongation%1  Schaaf2003Aged650CTempC2  \
# 0                         5.495901                 17.154805
# 1                         2.486663                357.641804
# 2                         3.217062                449.311317
# 3                              NaN                503.936576
# 4                              NaN                553.262289
# 5                              NaN                654.563990
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.13.  Stress-Strain Curves (Linear Hardening)</h3m> ¶

# %%
# Define your functions (replace with actual implementations)
def FractureStrength(T): return 0.45*(UltimateStrength(T))  # Replace with actual functionsource: Materna-Morris2015

# Define stress-strain curve function
def stress_strain_curve(T, shift=0):
    # Point 0 (0, 0)
    x0, y0 = 0 + shift, 0
    
    # Point 1 (at Yield Strength with slope = Young's Modulus)
    y1 = YieldStrength(T)
    x1 = 1e-3*100*y1 / YoungsModulus(T) + shift  # x1 = y1 / slope, modulus is in GPa and strain is in %
    
    # Point 2 (Ultimate strength at Uniform Elongation)
    x2 = UniformElongation(T) + shift
    y2 = UltimateStrength(T)
    
    # Point 3 (Fracture Strength at Total Elongation)
    x3 = TotalElongation(T) + shift
    y3 = FractureStrength(T)
    
    # Point 4 (0 stress at 1.1 * Total Elongation)
    x4 = 1.1 * TotalElongation(T) + shift
    y4 = 0
    
    # Define the points for stress-strain
    x_values = [x0, x1, x2, x3, x4]
    y_values = [y0, y1, y2, y3, y4]
    
    return x_values, y_values

# Define a function to plot multiple stress-strain curves
def plot_multiple_stress_strain(temperatures, shift_percent=0.2):
    plt.figure()
    
    # Plot each curve with a shift in strain values
    for i, T in enumerate(temperatures):
        shift = i * shift_percent * TotalElongation(T)  # Shift by 20% of Total Elongation for clarity
        x_values, y_values = stress_strain_curve(T, shift=shift)
        plt.plot(x_values, y_values, marker='', linestyle='-', label=f'{T-273} °C')
    
    plt.xlabel('Strain [%]', fontsize=16)  # Set font size for x-axis label
    plt.ylabel('Stress [MPa]', fontsize=16)  # Set font size for y-axis label
    plt.title('Stress-Strain Curves at Different Temperatures', fontsize=16)  # Set font size for title
    
    
    # Modify legend position and line thickness, and remove data points
    plt.legend(loc='best', fontsize=10)  # Control legend position (e.g., 'upper right', 'lower left')
    
    # Control line thickness
    for line in plt.gca().get_lines():
        line.set_linewidth(2)  # Set the line thickness to 2
    
    # Control graph size and center it in the page
    plt.gcf().set_size_inches(10, 6)  # Set figure size (width, height in inches)
    plt.gcf().subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)  # Centering the graph
    
    plt.grid(True)
    plt.xlim(0, max(x_values) + 5)  # Adjust x-axis limit for better visualization
    plt.ylim(0, 700)  # Adjust y-axis limit as needed
    plt.tick_params(axis='both', which='major', labelsize=16)  # Set font size for tick labels

    plt.show()


temperatures = [273 + T for T in [25, 100, 200, 300, 400, 450, 500, 550, 600]]  # Temperature values in Kelvin
plot_multiple_stress_strain(temperatures,0.2)

display(Markdown('Data sources: [Materna-Morris2015](https://drive.google.com/file/d/12Cu_rVfWnsL-JG9C69KMuwGg6gelFUja/view?usp=drive_link)'))
# Out:
# Data sources: [Materna-Morris2015](https://drive.google.com/file/d/12Cu_rVfWnsL-JG9C69KMuwGg6gelFUja/view?usp=drive_link)

# %% [markdown]
# <a id=cp></a>
# <h3>2.14.  Tangent Modulus (Linear Hardening)</h3m> ¶

# %%
# Define the Tangent Modulus function
def TangentModulus(T):
    return 1e-3*(UltimateStrength(T) - YieldStrength(T)) / (UniformElongation(T)/100 - 0.002)  #GPa

# Define the temperature array (100 values between 25 and 625)
T_K = 273 + np.linspace(25, 625, 100)

# Calculate Tangent Modulus for each T
tangent_modulus_values = [TangentModulus(T) for T in T_K]
T_C=T_K-273
# Plot the results
plt.plot(T_C, tangent_modulus_values, marker='', linestyle='-', label='Tangent Modulus')
plt.xlabel('Temperature [$^\circ$C]', fontsize=16)
plt.ylabel('Tangent Modulus [GPa]', fontsize=16)
plt.title('Tangent Modulus as a function of Temperature', fontsize=16)

    # Modify legend position and line thickness, and remove data points
plt.legend(loc='best', fontsize=14)  # Control legend position (e.g., 'upper right', 'lower left')
    
# Control line thickness
for line in plt.gca().get_lines():
    line.set_linewidth(3)  # Set the line thickness to 3

# Control graph size and center it in the page
plt.gcf().set_size_inches(10, 6)  # Set figure size (width, height in inches)
plt.gcf().subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)  # Centering the graph

plt.grid(True)
plt.xlim(0, max(T_C) + 5)  # Adjust x-axis limit for better visualization
plt.ylim(0, 2)  # Adjust y-axis limit as needed
plt.tick_params(axis='both', which='major', labelsize=16)  # Set font size for tick labels

plt.show()

# %% [markdown]
# <a id=cp></a>
# <h3>2.15.  Stress-Strain Curves (Ramberg-Osgood)</h3m> ¶
# <h4>2.15.1 Strain hardening exponent

# %%
# Define the Tangent Modulus function
def StrainHardeningExponent(T):
    return (np.log(UltimateStrength(T) / YieldStrength(T)))**0.75 / 6

# Define the temperature array (100 values between 25 and 625)
T_K = 273 + np.linspace(25, 625, 100)

# Calculate Tangent Modulus for each T
exponent_values = [StrainHardeningExponent(T) for T in T_K]
T_C=T_K-273
# Plot the results
plt.plot(T_C, exponent_values, marker='', linestyle='-', label='Strain Hardening Expo')
plt.xlabel('Temperature [$^\circ$C]', fontsize=16)
plt.ylabel('Strain Hardening Exponent', fontsize=16)
plt.title('Strain Hardening Exponent as a function of Temperature', fontsize=16)

    # Modify legend position and line thickness, and remove data points
plt.legend(loc='best', fontsize=14)  # Control legend position (e.g., 'upper right', 'lower left')
    
# Control line thickness
for line in plt.gca().get_lines():
    line.set_linewidth(3)  # Set the line thickness to 3

# Control graph size and center it in the page
plt.gcf().set_size_inches(10, 6)  # Set figure size (width, height in inches)
plt.gcf().subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)  # Centering the graph

plt.grid(True)
plt.xlim(0, max(T_C) + 5)  # Adjust x-axis limit for better visualization
plt.ylim(0, 0.1)  # Adjust y-axis limit as needed
plt.tick_params(axis='both', which='major', labelsize=16)  # Set font size for tick labels

plt.show()

# %% [markdown]
# <h4>2.15.2 Strength Coefficient

# %%
# Define the Tangent Modulus function
def StrengthCoefficient(T):
    return YieldStrength(T)/0.002**StrainHardeningExponent(T)  #MPa

# Define the temperature array (100 values between 25 and 625)
T_K = 273 + np.linspace(25, 625, 100)

# Calculate H for each T
H_values = [StrengthCoefficient(T) for T in T_K]
T_C=T_K-273
# Plot the results
plt.plot(T_C, H_values, marker='', linestyle='-', label='Strength Coefficient')
plt.xlabel('Temperature [$^\circ$C]', fontsize=16)
plt.ylabel('Strength Coefficient [MPa]', fontsize=16)
plt.title('Strength Coefficient as a function of Temperature', fontsize=16)

    # Modify legend position and line thickness, and remove data points
plt.legend(loc='best', fontsize=14)  # Control legend position (e.g., 'upper right', 'lower left')
    
# Control line thickness
for line in plt.gca().get_lines():
    line.set_linewidth(3)  # Set the line thickness to 3

# Control graph size and center it in the page
plt.gcf().set_size_inches(10, 6)  # Set figure size (width, height in inches)
plt.gcf().subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)  # Centering the graph

plt.grid(True)
plt.xlim(0, max(T_C) + 5)  # Adjust x-axis limit for better visualization
plt.ylim(0, 1000)  # Adjust y-axis limit as needed
plt.tick_params(axis='both', which='major', labelsize=16)  # Set font size for tick labels

plt.show()

# %% [markdown]
# <h4>2.15.3 Ramberg-Osgood Stress-Strain Curves

# %%
# Function to calculate strain based on modulus, strength coefficient, and hardening exponent
def calculate_strain(sigma_tilde, T):
    eps_tilde_e = sigma_tilde / YoungsModulus(T)
    n = StrainHardeningExponent(T)
    H = StrengthCoefficient(T)
    eps_tilde_p = (sigma_tilde / H) ** (1.0 / n)
    return eps_tilde_e + eps_tilde_p

del_sig = 10
sigma_tilde = np.arange(0, 1000 + del_sig, del_sig)
sig_size = len(sigma_tilde)
x_ro = np.zeros(sig_size)
y_ro = np.zeros(sig_size)
cntr = -1

for T in [20,300, 450]:
    T_K = T + 273  # Convert to Kelvin
    cntr += 1
    shift = cntr * 0

    # Calculate strain
    eps_tilde = calculate_strain(sigma_tilde, T_K)
    e_max = TotalElongation(T_K)
    
    # Romberg-Osgood True Stress-Strain Diagrams
    for i in range(sig_size):
        x_ro[i] = eps_tilde[i]
        y_ro[i] = sigma_tilde[i]
    
    # Limit the data to the values where strain is less than or equal to e_max
    mask = x_ro <= e_max
    x_ro_limited = x_ro[mask]
    y_ro_limited = y_ro[mask]
    
    # Plot True Stress-Strain with temperature label, limited by e_max
    plt.figure(10)
    generic_plot(x_ro_limited, y_ro_limited, shift, r'True $\sigma - \epsilon$ for Eurofer',
                 'Strain [%]', 'Stress [MPa]', [0, 30], [0, 1000], label=f'{T}°C')

    # Engineering Stress-Strain Diagrams
    e_ro = 100 * (np.exp(x_ro_limited / 100) - 1)
    sig_ro = np.exp(-x_ro_limited / 100) * y_ro_limited
    
    # Plot Engineering Stress-Strain with temperature label
    plt.figure(20)
    generic_plot(e_ro, sig_ro, shift, r'Engineering $\sigma - \epsilon$ for Eurofer',
                 'Strain [%]', 'Stress [MPa]', [0, 30], [0, 1000], label=f'{T}°C')

plt.show()


display(Markdown('Data sources: [Materna-Morris2015](https://drive.google.com/file/d/12Cu_rVfWnsL-JG9C69KMuwGg6gelFUja/view?usp=drive_link)'))
# Out:
# Data sources: [Materna-Morris2015](https://drive.google.com/file/d/12Cu_rVfWnsL-JG9C69KMuwGg6gelFUja/view?usp=drive_link)

# %% [markdown]
# <a id=cp></a>
# <h3>2.12. Toughness</h3m>

# %%
material_property = "Toughness"
var_names, variables, df = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=8)
x_label = 'Temperature [K]'
y_label = 'Absorbed Energy [J] '
x_lim=[0, 800]
y_lim=[0, 350]
headings = df.columns
data_labels = [headings[1], headings[3], headings[5], headings[7], headings[9]]

# Concatenate and sort data for fitting
vars_x = [RT + x for x in variables[::2]]
vars_y = variables[1::2]
T_data, Y_data = concatenate_and_sort(vars_x, vars_y)
data_marker_sizes = [m_size] * len(vars_x)

# Fit the data
p = [0, 300, 0, 200,100]
fit_result = get_model_fit_and_print_it(T_data, Y_data, fit_func='transition', param_initials=p, method='leastsq',\
    material_name=material_name, property_name=material_property, eq_digits=4, print_bool=True)
T1 = np.arange(0, 1000, 10)

plot_data(vars_x, vars_y, T1, fit_result, f_size, data_marker_sizes, x_label, y_label, x_lim, y_lim, data_labels,\
          'Eurofer97 Toughness','best', legend_font_size=6)

display(Markdown('Data sources: [Tavassoli2004](https://drive.google.com/file/d/1MIqQqASaKHNNw1S1WN10kY6QAHw2bBct/view?usp=drive_link), \
[Lindau2001](https://drive.google.com/file/d/1ZOtuTBGA3HUWj9WNKXHR_uNYR1pJNHmW/view?usp=drive_link)'))

p = [fit_result.params[key].value for key in fit_result.params]  # Extract parameter values as a list

# Define the polynomial function
def AbsorbedEnergy(T):
    return p[0] + 0.5 * (p[1] - p[0] + p[2] * T) * (1 + np.tanh((T - p[3]) / p[4]))

print(AbsorbedEnergy(200))
# Out:
#    EUROFER97SolidHIPJointTempC  EUROFER97SolidHIPJointEnergyJ/cm^2  \
# 0                  -195.475113                            4.517469
# 1                   -52.488688                           65.876048
# 2                   -22.624434                           87.248720
# 3                    -3.619910                          178.681107
# 4                    20.814480                          208.649210
# 5                   200.904977                          212.296936
# 6                   400.000000                          208.606557
# 7                          NaN                                 NaN
#
#    EUROFER97SolidHIPBulkTempC1  EUROFER97SolidHIPBulkEnergyJ/cm^21  \
# 0                  -191.855204                            5.754395
# 1                   -53.393665                           65.464357
# 2                   -21.719457                          102.824345
# 3                    -3.619910                          171.304058
# ...

# %% [markdown]
# <a id=cp></a>
# <h3>2.13. Creep</h3m>

# %%
material_property = "Creep"
var_names, variables = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=10, room_temp=293)
# Out:
#    EUROFER97600CTimeh  EUROFER97600CStressIntensityStMPa  EUROFER97550CTimeh1  \
# 0                  10                          123.97806                   10
# 1                  30                          113.80448                   30
# 2                 100                          103.06742                  100
# 3                 300                           92.89384                  300
# 4                1000                           82.72631                 1000
# 5                3000                           73.12159                 3000
# 6               10000                           64.09042                10000
# 7               30000                           55.05388                30000
# 8              100000                           44.88500               100000
# 9              300000                           36.98483               300000
#
#    EUROFER97550CStressIntensityStMPa1  EUROFER97500CTimeh2  \
# ...

# %%
# Temperature range and initializations
T = np.arange(10, 300000, 10)
n = len(T)

# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]

T, k = concatenate_and_sort(vars_x, vars_y)

x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_colors = ['green', 'red', 'magenta', 'blue', 'cyan', 'black', 'orange', 'purple', ]
data_marker_sizes = [msize] * len(x_data_list)
data_labels = ['Aiello', 'Aiello', 'Aiello', 'Aiello', 'Gaganidze']

fit_result = get_model_fit_and_print_it(T, k, fit_func='poly', fit_fun_args_and_initials={'a':1, 'b':1, 'c':1, 'd':1}, material_name=material_name, property_name=material_property, eq_digits=6, print_bool=True)

custom_multi_plot(x_data_list, y_data_list,
                  x_label='Temperature [K]', y_label=r'Specific Heat [J/Kg.K]', title=material_property + " of " + material_name,
                  scale='linear', font_size=fsize, xlim=[10, 300000], ylim=[0, 300], 
                  grid=True, legend=True, data_labels=data_labels, fit_labels=None,
                  data_colors=data_colors, fit_colors=None, data_marker_sizes=data_marker_sizes, 
                  fit_line_widths=[2], x_label_font_size=fsize, y_label_font_size=fsize, title_font_size=fsize, 
                  legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2)
# 
plot_fit_and_conf(T, fit_result, sigma=2, legend=True, legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2,
                  fit_line_color='red', pred_int_fill_color='grey', conf_int_fill_color='blue')

# %% [markdown]
# <a id=cp></a>
# <h3>2.14. Fatigue</h3m>

# %%
material_property = "Fatigue"
var_names, variables = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=31, room_temp=293)

# %%
# Temperature range and initializations
T = np.arange(10, 1000000, 10)
n = len(T)

# Concatenate and sort data for fitting
vars_x = variables[::2] 
vars_y = variables[1::2]

T, k = concatenate_and_sort(vars_x, vars_y)

x_data_list = [x for x in vars_x]
y_data_list = vars_y
data_colors = ['green', 'red', 'magenta', 'blue', 'cyan', 'black', 'orange', 'purple', ]
data_marker_sizes = [msize] * len(x_data_list)
data_labels = ['Aiello', 'Aiello', 'Roldán', 'Roldán', 'Roldán', 'Gaganidze', 'Gaganidze']

fit_result = get_model_fit_and_print_it(T, k, fit_func='poly', fit_fun_args_and_initials={'a':1, 'b':1, 'c':1, 'd':1}, material_name=material_name, property_name=material_property, eq_digits=6, print_bool=True)

custom_multi_plot(x_data_list, y_data_list,
                  x_label='Temperature [K]', y_label=r'Specific Heat [J/Kg.K]', title=material_property + " of " + material_name,
                  scale='linear', font_size=fsize, xlim=[10, 1000000], ylim=[0, 2], 
                  grid=True, legend=True, data_labels=data_labels, fit_labels=None,
                  data_colors=data_colors, fit_colors=None, data_marker_sizes=data_marker_sizes, 
                  fit_line_widths=[2], x_label_font_size=fsize, y_label_font_size=fsize, title_font_size=fsize, 
                  legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2)
# 
plot_fit_and_conf(T, fit_result, sigma=2, legend=True, legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2,
                  fit_line_color='red', pred_int_fill_color='grey', conf_int_fill_color='blue')

# %%
# Define the initial values for the array p
p = np.array([2, 4, 30, 2, 3,20])

# Define the Dip(T) function based on the provided formula
def Dip(T, p):
    return p[0] + 0.5 * (p[1] - p[0]) * (1 + np.tanh(T - p[2])) + p[3] - 0.5 * (p[4] - p[3]) * (1 + np.tanh(T - p[5]))

# Create the range for T
T = np.linspace(0, 50, 400)

# Calculate the Dip(T) values
Dip_T = Dip(T, p)

# Create the plot
plt.figure()
plt.plot(T, Dip_T)
plt.title('Plot of Dip(T) with initial array p')
plt.xlabel('T')
plt.ylabel('Dip(T)')
plt.grid(True)
plt.show()
