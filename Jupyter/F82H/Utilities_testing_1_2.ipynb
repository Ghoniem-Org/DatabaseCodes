# %%
from Utilities_modeling_1_2 import *
from Utilities_plots_1_2 import *

# Excel spreadsheet and material name strings
excel_filename = 'Eurofer_example_Qihan.xlsx'

# Load excel data for desired property name
material_property = "Eurofer_strength"

# Load the data from the Excel file

# 3rd argument is header_rows_list, containing a minimum of 1 and a maximum of 2 row integers
# Denotes what rows to consider in constructing variable names -
# If two row integers are given, then the first row (e.g. material name) is used as a prefix,
# while the second row (e.g. indepedent or dependent variable) is used as a suffix.
# If two row integers are given, it is assume that the format is:
# |                  Material Name 1              |   ...   |                  Material Name n              |
# | Independent variable 1 | Dependent variable 1 |   ...   | Independent variable n | Dependent variable n |

# If only one row integers are given, it is assume that the format is:
# | Independent variable 1 | Dependent variable 1 |   ...   | Independent variable n | Dependent variable n |

# Row integers start counting from 1 like in an Excel spreadsheet.

# 4th argument is num_data_rows, which is how many rows contain data.

var_names, variables = load_data(excel_filename, material_property, header_rows_list=[1, 3], num_data_rows=20, room_temp=293)
# Out:
# C:\Users\indro\Documents\GhoniemDesktop\Utilities_modeling_1_2.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   temp_data = pd.read_excel(filename, sheet_name=sheet_name, header=header_rows_list[-1]-1, nrows=num_data_rows, usecols=cols_with_data).replace('RT', room_temp)
#     EUROFER97TempC  EUROFER97YieldStrengthMPa  EUROFER97SyTempC1  \
# 0               20                 547.858099               20.0
# 1               50                 525.368139              100.0
# 2              100                 508.768407              150.0
# 3              150                 494.846051              200.0
# 4              200                 486.278447              250.0
# 5              250                 479.317269              300.0
# 6              300                 471.820616              350.0
# 7              350                 462.717537              400.0
# 8              400                 448.795181              450.0
# 9              450                 427.376171              500.0
# 10             500                 397.925033              550.0
# 11             550                 355.622490              600.0
# 12             600                 299.933066              650.0
# 13             650                 228.179384              700.0
# 14             700                 137.148594                NaN
#
#     EUROFER97SyYieldStrengthMPa1  EUROFER97SuTempC2  \
# 0                      511.72884               20.0
# 1                      476.28520              100.0
# 2                      461.81125              150.0
# 3                      452.56896              200.0
# 4                      445.93818              250.0
# 5                      436.69732              300.0
# 6                      427.45072              350.0
# 7                      410.36382              400.0
# 8                      388.04959              450.0
# 9                      353.96629              500.0
# 10                     310.73839              550.0
# 11                     253.12703              600.0
# 12                     178.52503              650.0
# 13                      81.69784              700.0
# 14                           NaN                NaN
#
#     EUROFER97SuUltimateTensileStrengthMPa  EUROFER979791h51TempC3  \
# 0                               634.60653              293.000000
# 1                               593.93268              291.219554
# 2                               570.30981              391.185488
# 3                               551.91572              496.567876
# 4                               534.82883              595.809913
# 5                               515.12754              697.649463
# 6                               495.42626                     NaN
# 7                               466.57318                     NaN
# 8                               432.49275                     NaN
# 9                               389.26197                     NaN
# 10                              339.49809                     NaN
# 11                              276.65653                     NaN
# 12                              199.44013                     NaN
# 13                              105.22734                     NaN
# 14                                    NaN                     NaN
#
#     EUROFER979791h51TensileStrengthMPa  EUROFER97ODSSyTempC4  \
# 0                           682.894737                 293.0
# 1                           552.631579                 300.0
# 2                           507.894737                 400.0
# 3                           426.315789                 500.0
# 4                           293.421053                 600.0
# 5                           159.210526                 700.0
# 6                                  NaN                   NaN
# 7                                  NaN                   NaN
# 8                                  NaN                   NaN
# 9                                  NaN                   NaN
# 10                                 NaN                   NaN
# 11                                 NaN                   NaN
# 12                                 NaN                   NaN
# 13                                 NaN                   NaN
# 14                                 NaN                   NaN
#
#     EUROFER97ODSSyYieldStrengthMPa2  EUROFER97ODSSuTempC5  \
# 0                             886.0                 293.0
# 1                             727.0                 300.0
# 2                             741.0                 400.0
# 3                             537.0                 500.0
# 4                             330.0                 600.0
# 5                             163.0                 700.0
# 6                               NaN                   NaN
# 7                               NaN                   NaN
# 8                               NaN                   NaN
# 9                               NaN                   NaN
# 10                              NaN                   NaN
# 11                              NaN                   NaN
# 12                              NaN                   NaN
# 13                              NaN                   NaN
# 14                              NaN                   NaN
#
#     EUROFER97ODSSuUltimateTensileStrengthMPa1
# 0                                      1066.0
# 1                                       913.0
# 2                                       840.0
# 3                                       685.0
# 4                                       428.0
# 5                                       247.0
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN

# %%
# WEIBULL FITTING FUNCTION TESTING

material_name = "F82H"
material_property = "Yield Strength"

# Font and marker sizes for plotting
fsize = 10 # font size
msize = 10 # marker size

a_test = 1
b_test = 0
c_test = 1.5
test_pts = 200
weibull_x_test = np.linspace(0.01, 2.5, test_pts)
weibull_y_test = np.zeros(test_pts)

for i in range(0, test_pts):
    weibull_y_test[i] = weibull(weibull_x_test[i], a_test, b_test, c_test)

weibull_y_test += 0.3*np.random.randn(test_pts)

plt.plot(weibull_x_test, weibull_y_test)

p = [a_test, np.nan, c_test]

fit_result = get_model_fit_and_print_it(weibull_x_test, weibull_y_test, fit_func='weibull', method='leastsq',\
    param_initials=p, material_name=material_name, property_name=material_property, eq_digits=3, print_bool=True)

plot_fit_and_conf(weibull_x_test, fit_result, sigma=2, legend=True, legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2,\
                  fit_line_color='red', pred_int_fill_color='grey', conf_int_fill_color='blue')
# Out:
# <hr>
# **Fitting parameters for F82H Yield Strength**
# [[Model]]
#     Model(weibull)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 200
#     # variables        = 2
#     chi-square         = 18.0914602
#     reduced chi-square = 0.09137101
#     Akaike info crit   = -476.575470
#     Bayesian info crit = -469.978835
#     R-squared          = 0.38815729
# [[Variables]]
#     p_0:  0.98669607 +/- 0.04954573 (5.02%) (init = 1)
#     p_1:  0 (fixed)
#     p_2:  1.44286302 +/- 0.07341395 (5.09%) (init = 1.5)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(p_0, p_2) = -0.2346
# <hr>
# **The equation for F82H Yield Strength is:**
# $\boxed{ 1.47 T^{4.43 \cdot 10^{-1}} e^{- 1.02 T^{1.44}} }$

# %%
# EXPONENTIAL FITTING FUNCTION TESTING

a_test = 1
b_test = 1
c_test = 1
d_test = 1
test_pts = 200
exponential_x_test = np.linspace(0.1, 1, test_pts)
exponential_y_test = np.zeros(test_pts)

for i in range(0, test_pts):
    exponential_y_test[i] = exponential(exponential_x_test[i], a_test, b_test, c_test, d_test)

exponential_y_test += 0.025*np.random.randn(test_pts)

plt.plot(exponential_x_test, exponential_y_test)

p = [1, 1, 1, 1]

fit_result = get_model_fit_and_print_it(exponential_x_test, exponential_y_test, fit_func='exponential', method='least_squares',\
    param_initials=p, material_name=material_name, property_name=material_property, eq_digits=3, print_bool=True)

plot_fit_and_conf(exponential_x_test, fit_result, sigma=2, legend=True, legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2,\
                  fit_line_color='red', pred_int_fill_color='grey', conf_int_fill_color='blue')
# Out:
# <hr>
# **Fitting parameters for F82H Yield Strength**
# [[Model]]
#     Model(exponential)
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 62
#     # data points      = 200
#     # variables        = 4
#     chi-square         = 0.12245812
#     reduced chi-square = 6.2479e-04
#     Akaike info crit   = -1471.66071
#     Bayesian info crit = -1458.46744
#     R-squared          = 0.99958378
# [[Variables]]
#     p_0:  0.57669202 +/- 0.46345611 (80.36%) (init = 1)
#     p_1:  1.41447839 +/- 0.45351848 (32.06%) (init = 1)
#     p_2:  0.37640852 +/- 1.09783759 (291.66%) (init = 1)
#     p_3:  1.18600062 +/- 0.43998864 (37.10%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(p_0, p_1) = -0.9999
#     C(p_2, p_3) = -0.9997
#     C(p_1, p_2) = -0.9983
#     C(p_0, p_2) = +0.9976
#     C(p_1, p_3) = +0.9967
#     C(p_0, p_3) = -0.9958
# <hr>
# **The equation for F82H Yield Strength is:**
# $\boxed{ + 0.577 + \left(3.76 \cdot 10^{-1} T + 1.41\right) e^{1.19 T} }$

# %%
# TRANSITION FITTING FUNCTION TESTING

a_test = 1
b_test = 1
c_test = 1
d_test = 1
e_test = 1
test_pts = 200
transition_x_test = np.linspace(-5, 5, test_pts)
transition_y_test = np.zeros(test_pts)

for i in range(0, test_pts):
    transition_y_test[i] = transition(transition_x_test[i], a_test, b_test, c_test, d_test, e_test)

transition_y_test += 0.6*np.random.randn(test_pts)

plt.plot(transition_x_test, transition_y_test)

p = [1, 1, 1, 1, 1]
fit_result = get_model_fit_and_print_it(transition_x_test, transition_y_test, fit_func='transition', method='leastsq',\
    param_initials=p, material_name=material_name, property_name=material_property, eq_digits=3, print_bool=True)

plot_fit_and_conf(transition_x_test, fit_result, sigma=2, legend=True, legend_font_size=fsize, legend_loc='lower left', legend_num_cols=2,\
                  fit_line_color='red', pred_int_fill_color='grey', conf_int_fill_color='blue')
# Out:
# <hr>
# **Fitting parameters for F82H Yield Strength**
# [[Model]]
#     Model(transition)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 50
#     # data points      = 200
#     # variables        = 5
#     chi-square         = 74.5107660
#     reduced chi-square = 0.38210649
#     Akaike info crit   = -187.474748
#     Bayesian info crit = -170.983161
#     R-squared          = 0.88319305
# [[Variables]]
#     p_0:  0.93840341 +/- 0.06263211 (6.67%) (init = 1)
#     p_1:  2.31017064 +/- 1.18096594 (51.12%) (init = 1)
#     p_2:  0.71158990 +/- 0.26392275 (37.09%) (init = 1)
#     p_3:  1.73560480 +/- 0.34765414 (20.03%) (init = 1)
#     p_4:  1.06855641 +/- 0.29180743 (27.31%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(p_1, p_2) = -0.9937
#     C(p_1, p_3) = +0.9492
#     C(p_2, p_3) = -0.9353
#     C(p_1, p_4) = +0.7031
#     C(p_2, p_4) = -0.6562
#     C(p_3, p_4) = +0.6244
#     C(p_0, p_4) = -0.3603
#     C(p_0, p_1) = -0.2313
#     C(p_0, p_2) = +0.2192
#     C(p_0, p_3) = -0.1153
# <hr>
# **The equation for F82H Yield Strength is:**
# $\boxed{ + 0.938 + \left(3.56 \cdot 10^{-1} T + 6.86 \cdot 10^{-1}\right) \left(\tanh{\left(9.36 \cdot 10^{-1} T - 1.62 \right)} + 1\right) }$
